# %% [markdown]
# <a href="https://colab.research.google.com/github/Rayan-David/Aula02-listas-tuplas-dict/blob/main/aula2-atividades.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mat = ['Matematica','Historia','Biologia']
notas = (8.5, 9.0, 10.00)
dados = {
    'nome': 'Rayan',
    'idade': 18,
    'Curso': 'Ads'
}
print('Materias: ', mat)
print('Notas: ',notas)
print("informações do aluno: ",dados)
# Out:
# Materias:  ['Matematica', 'Historia', 'Biologia']
# Notas:  (8.5, 9.0, 10.0)
# informações do aluno:  {'nome': 'Rayan', 'idade': 18, 'Curso': 'Ads'}

# %%
aces = ['Farol', 'Para-Choque', 'Porta']
espci = ('Potencia do motor: 1200cv', 'Capacidade do tanque: 20L')
dados = {
    'Marca': 'Chevrolet',
    'Modelo': 'Camaro',
    'Ano': 1968
}
print('Acessorios do carro: ', aces)
print('Especificações: ', espci)
print('Informações do carro: ', dados)
# Out:
# Acessorios do carro:  ['Farol', 'Para-Choque', 'Porta']
# Especificações:  ('Potencia do motor: 1200cv', 'Capacidade do tanque: 20L')
# Informações do carro:  {'Marca': 'Chevrolet', 'Modelo': 'Camaro', 'Ano': 1968}
